# %%
# !pip install xlsxwriter

import requests
import xlsxwriter
import pandas as pd
import numpy as np
import openpyxl
from openpyxl import Workbook, load_workbook
from openpyxl.styles import Border, Side, Font, Alignment, PatternFill, numbers
# Out:
# Requirement already satisfied: xlsxwriter in c:\users\ilaes\appdata\local\programs\python\python311\lib\site-packages (3.2.0)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
API_KEY = "432a4eb88e28a33523cd7d3b3bcbc55c"
SPORT = "upcoming"
REGIONS = 'uk,us,us2,eu,au'
MARKETS = 'h2h'
ODDS_FORMAT = 'decimal'
DATE_FORMAT = 'iso'
BET_SIZE = 100
BOOKMAKERS = "betonlineag,sport888,betvictor,betway,pinnacle,mybookieag,coolbet,betrivers,casumo,leovegas,unibet_us"

odds_response = requests.get(
    f'https://api.the-odds-api.com/v4/sports/{SPORT}/odds',
    params={
        'api_key': API_KEY,
        'regions': REGIONS,
        'markets': MARKETS,
        'bookmakers': BOOKMAKERS,
        'oddsFormat': ODDS_FORMAT,
        'dateFormat': DATE_FORMAT,
    }
).json()

odds_response
# Out:
# [{'id': '70d63fed15f97ec7e77df5307424a393',
#   'sport_key': 'baseball_npb',
#   'sport_title': 'NPB',
#   'commence_time': '2024-04-04T04:00:00Z',
#   'home_team': 'Saitama Seibu Lions',
#   'away_team': 'Orix Buffaloes',
#   'bookmakers': [{'key': 'coolbet',
#     'title': 'Coolbet',
#     'last_update': '2024-04-04T06:50:29Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:50:29Z',
#       'outcomes': [{'name': 'Orix Buffaloes', 'price': 1.01},
#        {'name': 'Saitama Seibu Lions', 'price': 11.0}]}]},
#    {'key': 'sport888',
#     'title': '888sport',
#     'last_update': '2024-04-04T06:50:20Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:50:20Z',
#       'outcomes': [{'name': 'Orix Buffaloes', 'price': 1.02},
#        {'name': 'Saitama Seibu Lions', 'price': 17.0}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2024-04-04T06:48:33Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:48:33Z',
#       'outcomes': [{'name': 'Orix Buffaloes', 'price': 1.17},
#        {'name': 'Saitama Seibu Lions', 'price': 4.25}]}]}]},
#  {'id': '0d14df32cae7576b61b533a2925af25f',
#   'sport_key': 'aussierules_afl',
#   'sport_title': 'AFL',
#   'commence_time': '2024-04-04T08:40:00Z',
#   'home_team': 'Adelaide Crows',
#   'away_team': 'Melbourne Demons',
#   'bookmakers': [{'key': 'coolbet',
#     'title': 'Coolbet',
#     'last_update': '2024-04-04T06:49:32Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:49:32Z',
#       'outcomes': [{'name': 'Adelaide Crows', 'price': 2.5},
#        {'name': 'Melbourne Demons', 'price': 1.54}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2024-04-04T06:50:38Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:50:38Z',
#       'outcomes': [{'name': 'Adelaide Crows', 'price': 2.36},
#        {'name': 'Melbourne Demons', 'price': 1.52}]}]},
#    {'key': 'pinnacle',
#     'title': 'Pinnacle',
#     'last_update': '2024-04-04T06:49:42Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:49:42Z',
#       'outcomes': [{'name': 'Adelaide Crows', 'price': 2.67},
#        {'name': 'Melbourne Demons', 'price': 1.48}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2024-04-04T06:49:30Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:49:30Z',
#       'outcomes': [{'name': 'Adelaide Crows', 'price': 2.5},
#        {'name': 'Melbourne Demons', 'price': 1.54}]}]},
#    {'key': 'casumo',
#     'title': 'Casumo',
#     'last_update': '2024-04-04T06:49:30Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:49:30Z',
#       'outcomes': [{'name': 'Adelaide Crows', 'price': 2.5},
#        {'name': 'Melbourne Demons', 'price': 1.54}]}]},
#    {'key': 'leovegas',
#     'title': 'LeoVegas',
#     'last_update': '2024-04-04T06:49:30Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:49:30Z',
#       'outcomes': [{'name': 'Adelaide Crows', 'price': 2.4},
#        {'name': 'Melbourne Demons', 'price': 1.5}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2024-04-04T06:49:30Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:49:30Z',
#       'outcomes': [{'name': 'Adelaide Crows', 'price': 2.5},
#        {'name': 'Melbourne Demons', 'price': 1.54}]}]}]},
#  {'id': '3746f4486a9962abe9534b3889ed9c95',
#   'sport_key': 'rugbyleague_nrl',
#   'sport_title': 'NRL',
#   'commence_time': '2024-04-04T09:00:00Z',
#   'home_team': 'Melbourne Storm',
#   'away_team': 'Brisbane Broncos',
#   'bookmakers': [{'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2024-04-04T06:50:24Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:50:24Z',
#       'outcomes': [{'name': 'Brisbane Broncos', 'price': 2.99},
#        {'name': 'Melbourne Storm', 'price': 1.45},
#        {'name': 'Draw', 'price': 22.26}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2024-04-04T06:50:24Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:50:24Z',
#       'outcomes': [{'name': 'Brisbane Broncos', 'price': 2.75},
#        {'name': 'Melbourne Storm', 'price': 1.44}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2024-04-04T06:50:25Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:50:25Z',
#       'outcomes': [{'name': 'Brisbane Broncos', 'price': 2.75},
#        {'name': 'Melbourne Storm', 'price': 1.44}]}]},
#    {'key': 'casumo',
#     'title': 'Casumo',
#     'last_update': '2024-04-04T06:50:24Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:50:24Z',
#       'outcomes': [{'name': 'Brisbane Broncos', 'price': 2.75},
#        {'name': 'Melbourne Storm', 'price': 1.44}]}]},
#    {'key': 'leovegas',
#     'title': 'LeoVegas',
#     'last_update': '2024-04-04T06:50:25Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:50:25Z',
#       'outcomes': [{'name': 'Brisbane Broncos', 'price': 2.63},
#        {'name': 'Melbourne Storm', 'price': 1.42}]}]},
#    {'key': 'pinnacle',
#     'title': 'Pinnacle',
#     'last_update': '2024-04-04T06:49:57Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:49:57Z',
#       'outcomes': [{'name': 'Brisbane Broncos', 'price': 2.92},
#        {'name': 'Melbourne Storm', 'price': 1.44}]}]}]},
#  {'id': '13ab325c1230ef4fe11ea0ea3f820c76',
#   'sport_key': 'baseball_npb',
#   'sport_title': 'NPB',
#   'commence_time': '2024-04-04T09:00:00Z',
#   'home_team': 'Fukuoka SoftBank Hawks',
#   'away_team': 'Chiba Lotte Marines',
#   'bookmakers': [{'key': 'coolbet',
#     'title': 'Coolbet',
#     'last_update': '2024-04-04T06:50:29Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:50:29Z',
#       'outcomes': [{'name': 'Chiba Lotte Marines', 'price': 2.27},
#        {'name': 'Fukuoka SoftBank Hawks', 'price': 1.7}]}]},
#    {'key': 'pinnacle',
#     'title': 'Pinnacle',
#     'last_update': '2024-04-04T06:50:06Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:50:06Z',
#       'outcomes': [{'name': 'Chiba Lotte Marines', 'price': 2.24},
#        {'name': 'Fukuoka SoftBank Hawks', 'price': 1.71}]}]},
#    {'key': 'sport888',
#     'title': '888sport',
#     'last_update': '2024-04-04T06:50:20Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:50:20Z',
#       'outcomes': [{'name': 'Chiba Lotte Marines', 'price': 2.2},
#        {'name': 'Fukuoka SoftBank Hawks', 'price': 1.61}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2024-04-04T06:50:07Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:50:07Z',
#       'outcomes': [{'name': 'Chiba Lotte Marines', 'price': 2.15},
#        {'name': 'Fukuoka SoftBank Hawks', 'price': 1.65}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2024-04-04T06:50:06Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:50:06Z',
#       'outcomes': [{'name': 'Chiba Lotte Marines', 'price': 2.23},
#        {'name': 'Fukuoka SoftBank Hawks', 'price': 1.65}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2024-04-04T06:50:07Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:50:07Z',
#       'outcomes': [{'name': 'Chiba Lotte Marines', 'price': 2.23},
#        {'name': 'Fukuoka SoftBank Hawks', 'price': 1.65}]}]}]},
#  {'id': '0c4ed8d182d7c4a4871a08bae326e585',
#   'sport_key': 'baseball_npb',
#   'sport_title': 'NPB',
#   'commence_time': '2024-04-04T09:00:00Z',
#   'home_team': 'Chunichi Dragons',
#   'away_team': 'Yomiuri Giants',
#   'bookmakers': [{'key': 'coolbet',
#     'title': 'Coolbet',
#     'last_update': '2024-04-04T06:50:29Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:50:29Z',
#       'outcomes': [{'name': 'Chunichi Dragons', 'price': 2.4},
#        {'name': 'Yomiuri Giants', 'price': 1.63}]}]},
#    {'key': 'pinnacle',
#     'title': 'Pinnacle',
#     'last_update': '2024-04-04T06:50:06Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:50:06Z',
#       'outcomes': [{'name': 'Chunichi Dragons', 'price': 2.4},
#        {'name': 'Yomiuri Giants', 'price': 1.63}]}]},
#    {'key': 'sport888',
#     'title': '888sport',
#     'last_update': '2024-04-04T06:50:20Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:50:20Z',
#       'outcomes': [{'name': 'Chunichi Dragons', 'price': 2.25},
#        {'name': 'Yomiuri Giants', 'price': 1.57}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2024-04-04T06:50:20Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:50:20Z',
#       'outcomes': [{'name': 'Chunichi Dragons', 'price': 2.41},
#        {'name': 'Yomiuri Giants', 'price': 1.62}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2024-04-04T06:50:07Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:50:07Z',
#       'outcomes': [{'name': 'Chunichi Dragons', 'price': 2.4},
#        {'name': 'Yomiuri Giants', 'price': 1.55}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2024-04-04T06:50:07Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:50:07Z',
#       'outcomes': [{'name': 'Chunichi Dragons', 'price': 2.3},
#        {'name': 'Yomiuri Giants', 'price': 1.56}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2024-04-04T06:50:06Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:50:06Z',
#       'outcomes': [{'name': 'Chunichi Dragons', 'price': 2.4},
#        {'name': 'Yomiuri Giants', 'price': 1.55}]}]}]},
#  {'id': 'fe37739804833e2d3ad35072e6231ffa',
#   'sport_key': 'baseball_npb',
#   'sport_title': 'NPB',
#   'commence_time': '2024-04-04T09:00:00Z',
#   'home_team': 'Hanshin Tigers',
#   'away_team': 'Yokohama DeNA BayStars',
#   'bookmakers': [{'key': 'coolbet',
#     'title': 'Coolbet',
#     'last_update': '2024-04-04T06:50:29Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:50:29Z',
#       'outcomes': [{'name': 'Hanshin Tigers', 'price': 1.7},
#        {'name': 'Yokohama DeNA BayStars', 'price': 2.27}]}]},
#    {'key': 'pinnacle',
#     'title': 'Pinnacle',
#     'last_update': '2024-04-04T06:50:06Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:50:06Z',
#       'outcomes': [{'name': 'Hanshin Tigers', 'price': 1.7},
#        {'name': 'Yokohama DeNA BayStars', 'price': 2.27}]}]},
#    {'key': 'sport888',
#     'title': '888sport',
#     'last_update': '2024-04-04T06:50:20Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:50:20Z',
#       'outcomes': [{'name': 'Hanshin Tigers', 'price': 1.61},
#        {'name': 'Yokohama DeNA BayStars', 'price': 2.2}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2024-04-04T06:50:20Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:50:20Z',
#       'outcomes': [{'name': 'Hanshin Tigers', 'price': 1.68},
#        {'name': 'Yokohama DeNA BayStars', 'price': 2.27}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2024-04-04T06:50:07Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:50:07Z',
#       'outcomes': [{'name': 'Hanshin Tigers', 'price': 1.65},
#        {'name': 'Yokohama DeNA BayStars', 'price': 2.15}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2024-04-04T06:50:07Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:50:07Z',
#       'outcomes': [{'name': 'Hanshin Tigers', 'price': 1.67},
#        {'name': 'Yokohama DeNA BayStars', 'price': 2.18}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2024-04-04T06:50:06Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:50:06Z',
#       'outcomes': [{'name': 'Hanshin Tigers', 'price': 1.67},
#        {'name': 'Yokohama DeNA BayStars', 'price': 2.18}]}]}]},
#  {'id': '9540b10f0e10ceb09fe4538df06c30b8',
#   'sport_key': 'baseball_npb',
#   'sport_title': 'NPB',
#   'commence_time': '2024-04-04T09:00:00Z',
#   'home_team': 'Hiroshima Toyo Carp',
#   'away_team': 'Tokyo Yakult Swallows',
#   'bookmakers': [{'key': 'coolbet',
#     'title': 'Coolbet',
#     'last_update': '2024-04-04T06:50:29Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:50:29Z',
#       'outcomes': [{'name': 'Hiroshima Toyo Carp', 'price': 1.78},
#        {'name': 'Tokyo Yakult Swallows', 'price': 2.13}]}]},
#    {'key': 'pinnacle',
#     'title': 'Pinnacle',
#     'last_update': '2024-04-04T06:50:06Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:50:06Z',
#       'outcomes': [{'name': 'Hiroshima Toyo Carp', 'price': 1.81},
#        {'name': 'Tokyo Yakult Swallows', 'price': 2.1}]}]},
#    {'key': 'sport888',
#     'title': '888sport',
#     'last_update': '2024-04-04T06:50:20Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:50:20Z',
#       'outcomes': [{'name': 'Hiroshima Toyo Carp', 'price': 1.73},
#        {'name': 'Tokyo Yakult Swallows', 'price': 2.0}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2024-04-04T06:50:20Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:50:20Z',
#       'outcomes': [{'name': 'Hiroshima Toyo Carp', 'price': 1.78},
#        {'name': 'Tokyo Yakult Swallows', 'price': 2.08}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2024-04-04T06:50:07Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:50:07Z',
#       'outcomes': [{'name': 'Hiroshima Toyo Carp', 'price': 1.71},
#        {'name': 'Tokyo Yakult Swallows', 'price': 2.0}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2024-04-04T06:50:07Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:50:07Z',
#       'outcomes': [{'name': 'Hiroshima Toyo Carp', 'price': 1.71},
#        {'name': 'Tokyo Yakult Swallows', 'price': 2.1}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2024-04-04T06:50:06Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:50:06Z',
#       'outcomes': [{'name': 'Hiroshima Toyo Carp', 'price': 1.71},
#        {'name': 'Tokyo Yakult Swallows', 'price': 2.1}]}]}]},
#  {'id': 'af4709ed8c649b43eaaf3ef5c9c364a5',
#   'sport_key': 'baseball_kbo',
#   'sport_title': 'KBO',
#   'commence_time': '2024-04-04T09:30:00Z',
#   'home_team': 'SSG Landers',
#   'away_team': 'Doosan Bears',
#   'bookmakers': [{'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2024-04-04T06:49:48Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:49:48Z',
#       'outcomes': [{'name': 'Doosan Bears', 'price': 1.67},
#        {'name': 'SSG Landers', 'price': 2.3}]}]},
#    {'key': 'coolbet',
#     'title': 'Coolbet',
#     'last_update': '2024-04-04T06:48:42Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:48:42Z',
#       'outcomes': [{'name': 'Doosan Bears', 'price': 1.71},
#        {'name': 'SSG Landers', 'price': 2.25}]}]},
#    {'key': 'pinnacle',
#     'title': 'Pinnacle',
#     'last_update': '2024-04-04T06:49:55Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:49:55Z',
#       'outcomes': [{'name': 'Doosan Bears', 'price': 1.68},
#        {'name': 'SSG Landers', 'price': 2.24}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2024-04-04T06:50:13Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:50:13Z',
#       'outcomes': [{'name': 'Doosan Bears', 'price': 1.68},
#        {'name': 'SSG Landers', 'price': 2.14}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2024-04-04T06:50:27Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:50:27Z',
#       'outcomes': [{'name': 'Doosan Bears', 'price': 1.68},
#        {'name': 'SSG Landers', 'price': 2.14}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2024-04-04T06:50:12Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:50:12Z',
#       'outcomes': [{'name': 'Doosan Bears', 'price': 1.65},
#        {'name': 'SSG Landers', 'price': 2.15}]}]}]},
#  {'id': '2406d09c7ead267798a8278f8f7b0722',
#   'sport_key': 'baseball_kbo',
#   'sport_title': 'KBO',
#   'commence_time': '2024-04-04T09:30:00Z',
#   'home_team': 'Hanwha Eagles',
#   'away_team': 'Lotte Giants',
#   'bookmakers': [{'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2024-04-04T06:49:48Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:49:48Z',
#       'outcomes': [{'name': 'Hanwha Eagles', 'price': 1.8},
#        {'name': 'Lotte Giants', 'price': 2.05}]}]},
#    {'key': 'coolbet',
#     'title': 'Coolbet',
#     'last_update': '2024-04-04T06:48:42Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:48:42Z',
#       'outcomes': [{'name': 'Hanwha Eagles', 'price': 1.87},
#        {'name': 'Lotte Giants', 'price': 2.02}]}]},
#    {'key': 'pinnacle',
#     'title': 'Pinnacle',
#     'last_update': '2024-04-04T06:49:55Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:49:55Z',
#       'outcomes': [{'name': 'Hanwha Eagles', 'price': 1.81},
#        {'name': 'Lotte Giants', 'price': 2.05}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2024-04-04T06:50:27Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:50:27Z',
#       'outcomes': [{'name': 'Hanwha Eagles', 'price': 1.82},
#        {'name': 'Lotte Giants', 'price': 1.96}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2024-04-04T06:50:13Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:50:13Z',
#       'outcomes': [{'name': 'Hanwha Eagles', 'price': 1.82},
#        {'name': 'Lotte Giants', 'price': 1.96}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2024-04-04T06:50:12Z',
#     'markets': [{'key': 'h2h',
#       'last_update': '2024-04-04T06:50:12Z',
#       'outcomes': [{'name': 'Hanwha Eagles', 'price': 1.77},
#        {'name': 'Lotte Giants', 'price': 1.91}]}]}]}]

# %%
data = []
for event in odds_response:
    event_id = event['id']  # Unique identifier for the event
    sport = event['sport_title']
    sport_key = event['sport_key']
    commence_time = event['commence_time']
    home_team = event['home_team']
    away_team = event['away_team']
    for bookmaker in event['bookmakers']:
        bookmaker_key = bookmaker['key']
        bookmaker_title = bookmaker['title']
        bookmaker_last_update = bookmaker['last_update']
        for market in bookmaker['markets']:
            market_key = market['key']
            market_last_update = market['last_update']
            for outcome in market['outcomes']:
                outcome_name = outcome['name']
                odds = outcome['price']
                data.append([event_id, sport, sport_key, commence_time, home_team, away_team, bookmaker_key, bookmaker_title, bookmaker_last_update, market_key, market_last_update, outcome_name, odds])

# Creating DataFrame
columns = ['Event ID', 'Sport', 'Sport Key', 'Commence Time', 'Home Team', 'Away Team', 'Bookmaker Key', 'Bookmaker Title', 'Bookmaker Last Update', 'Market Key', 'Market Last Update', 'Outcome', 'Odds']
df = pd.DataFrame(data, columns=columns)

myBooks = ["betonlineag", "sport888", "betvictor", "betway", "pinnacle", "mybookieag", 
